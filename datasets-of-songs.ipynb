# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline

# %%
df_genre=pd.read_csv('archive/genres_v2.csv')
df_genre.head()
# Out:
# /home/abhilash/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
# ...

# %%
genre_columns=df_genre.columns
print(genre_columns)
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'genre', 'song_name', 'Unnamed: 0', 'title'],
#       dtype='object')

# %%
df_genre.describe(include='all')
# Out:
#         danceability        energy           key      loudness          mode  \
# count   42305.000000  42305.000000  42305.000000  42305.000000  42305.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.639364      0.762516      5.370240     -6.465442      0.549462
# std         0.156617      0.183823      3.666145      2.941165      0.497553
# min         0.065100      0.000243      0.000000    -33.357000      0.000000
# 25%         0.524000      0.632000      1.000000     -8.161000      0.000000
# 50%         0.646000      0.803000      6.000000     -6.234000      1.000000
# 75%         0.766000      0.923000      9.000000     -4.513000      1.000000
# max         0.988000      1.000000     11.000000      3.148000      1.000000
#
# ...

# %%
songsId=df_genre['id']
songsId
# Out:
# 0        2Vc6NJ9PW9gD9q343XFRKx
# 1        7pgJBLVz5VmnL7uGHmRj6p
# 2        0vSWgAlfpye0WCGeNmuNhy
# 3        0VSXnJqQkwuH2ei1nOQ1nu
# 4        4jCeguq9rMTlbMmPHuO7S3
#                   ...
# 42300    46bXU7Sgj7104ZoXxzz9tM
# 42301    0he2ViGMUO3ajKTxLOfWVT
# 42302    72DAt9Lbpy9EUS29OzQLob
# 42303    6HXgExFVuE1c3cq9QjFCcU
# 42304    6MAAMZImxcvYhRnxDLTufD
# Name: id, Length: 42305, dtype: object

# %%
df_genre.drop(['type'],axis=1,inplace=True)

# %%
df_genre.drop(['id'],axis=1,inplace=True)

# %%
df_genre.drop(['uri', 'track_href', 'analysis_url', 'duration_ms'],axis=1,inplace=True)

# %%
df_genre.drop([ 'song_name', 'Unnamed: 0', 'title'],axis=1,inplace=True)

# %%
df_genre.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence    tempo  time_signature      genre
# 0          0.013400    0.0556   0.3890  156.985               4  Dark Trap
# 1          0.000000    0.1180   0.1240  115.080               4  Dark Trap
# 2          0.000004    0.3720   0.0391  218.050               4  Dark Trap
# 3          0.000000    0.1140   0.1750  186.948               3  Dark Trap
# 4          0.000000    0.1660   0.5910  147.988               4  Dark Trap

# %%
df_genre.genre.value_counts()
# Out:
# Underground Rap    5875
# Dark Trap          4578
# Hiphop             3028
# trance             2999
# trap               2987
# techhouse          2975
# dnb                2966
# psytrance          2961
# techno             2956
# hardstyle          2936
# RnB                2099
# Trap Metal         1956
# Rap                1848
# Emo                1680
# Pop                 461
# Name: genre, dtype: int64

# %%
df_genre.genre.unique()
# Out:
# array(['Dark Trap', 'Underground Rap', 'Trap Metal', 'Emo', 'Rap', 'RnB',
#        'Pop', 'Hiphop', 'techhouse', 'techno', 'trance', 'psytrance',
#        'trap', 'dnb', 'hardstyle'], dtype=object)

# %%
genre_list=list(df_genre.genre.unique())
genre_list
# Out:
# ['Dark Trap',
#  'Underground Rap',
#  'Trap Metal',
#  'Emo',
#  'Rap',
#  'RnB',
#  'Pop',
#  'Hiphop',
#  'techhouse',
#  'techno',
#  'trance',
#  'psytrance',
#  'trap',
#  'dnb',
#  'hardstyle']

# %%
genres={}
for i in range(len(genre_list)):
    genres[genre_list[i]]=i
    
print(genres)
# Out:
# {'Dark Trap': 0, 'Underground Rap': 1, 'Trap Metal': 2, 'Emo': 3, 'Rap': 4, 'RnB': 5, 'Pop': 6, 'Hiphop': 7, 'techhouse': 8, 'techno': 9, 'trance': 10, 'psytrance': 11, 'trap': 12, 'dnb': 13, 'hardstyle': 14}

# %%
genreList=[]
for i in df_genre.genre:
    if i in genre_list:
        genreList.append(genres[i])

# %%
df_genre['Genres']=genreList

# %%
df_genre.drop(['genre'],inplace=True,axis=1)

# %%
print(df_genre.columns)
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'Genres'],
#       dtype='object')

# %%
Y=df_genre.Genres.values

# %%
df_genre.dtypes
# Out:
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# Genres                int64
# dtype: object

# %%
df_genre['mode']=df_genre['mode'].astype('str')

# %%
df_genre['key']=df_genre['key'].astype('str')

# %%
df_genre['time_signature']=df_genre['time_signature'].astype('str')

# %%
df_genre.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'Genres'],
#       dtype='object')

# %%
df_genre2=df_genre
df_genre2.head()
# Out:
#    danceability  energy key  loudness mode  speechiness  acousticness  \
# 0         0.831   0.814   2    -7.364    1       0.4200        0.0598
# 1         0.719   0.493   8    -7.230    1       0.0794        0.4010
# 2         0.850   0.893   5    -4.783    1       0.0623        0.0138
# 3         0.476   0.781   0    -4.710    1       0.1030        0.0237
# 4         0.798   0.624   2    -7.668    1       0.2930        0.2170
#
#    instrumentalness  liveness  valence    tempo time_signature  Genres
# 0          0.013400    0.0556   0.3890  156.985              4       0
# 1          0.000000    0.1180   0.1240  115.080              4       0
# 2          0.000004    0.3720   0.0391  218.050              4       0
# 3          0.000000    0.1140   0.1750  186.948              3       0
# 4          0.000000    0.1660   0.5910  147.988              4       0

# %%
df_genre2.drop(['Genres','time_signature'],inplace=True,axis=1)

# %%
df_genre2.head()
# Out:
#    danceability  energy key  loudness mode  speechiness  acousticness  \
# 0         0.831   0.814   2    -7.364    1       0.4200        0.0598
# 1         0.719   0.493   8    -7.230    1       0.0794        0.4010
# 2         0.850   0.893   5    -4.783    1       0.0623        0.0138
# 3         0.476   0.781   0    -4.710    1       0.1030        0.0237
# 4         0.798   0.624   2    -7.668    1       0.2930        0.2170
#
#    instrumentalness  liveness  valence    tempo
# 0          0.013400    0.0556   0.3890  156.985
# 1          0.000000    0.1180   0.1240  115.080
# 2          0.000004    0.3720   0.0391  218.050
# 3          0.000000    0.1140   0.1750  186.948
# 4          0.000000    0.1660   0.5910  147.988

# %%
X=df_genre2.values
Y
# Out:
# array([ 0,  0,  0, ..., 14, 14, 14])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)
print('X_train Shape: {}'.format(X_train.shape))
print('X_test Shape: {}'.format(X_test.shape))
print('Y_train Shape: {}'.format(y_train.shape))
print('Y_test Shape: {}'.format(y_test.shape))
# Out:
# X_train Shape: (33844, 11)
# X_test Shape: (8461, 11)
# Y_train Shape: (33844,)
# Y_test Shape: (8461,)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(n_estimators=1000)
clf.fit(X_train_scaled,y_train)
print(clf.score(X_test_scaled,y_test))
# Out:
# 0.6480321475002955

# %%
y_pred=clf.predict(X_test_scaled)
y_pred
# Out:
# array([ 7,  0,  1, ..., 10,  1,  1])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
fig,ax=plt.subplots(figsize=(20,10))
ax=sns.heatmap(cm,annot=True,fmt='')

ax.set_xlabel('Orginal Label')
ax.set_ylabel('Predicted Label')
# Out:
# Text(159.0, 0.5, 'Predicted Label')
